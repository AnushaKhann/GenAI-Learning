# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.2:1b")

# %%
res = llm.invoke("Hello, I am Anusha Khan. Can you tell me about yourself?")
res.text
# Out:
# "Hello Anusha Khan. I'm an artificial intelligence model, and I don't have a personal history or physical existence, but I can provide information about you if you'd like. I'm a large language model developed by the Meta AI team, and I'm here to assist with a wide range of topics and questions.\n\nAs a conversational AI, I don't have personal experiences, emotions, or physical interactions. I exist solely to provide information and help users like you with their queries. I can draw from my vast knowledge base to provide answers to your questions, but I don't have personal preferences, opinions, or biases.\n\nIf you're interested in learning more about me or our conversation, I can tell you that I'm designed to be helpful, informative, and engaging. I'm constantly learning and improving, and I appreciate the opportunity to interact with users like you.\n\nWhat would you like to talk about, Anusha Khan?"

# %%
res.content
# Out:
# "Hello Anusha Khan. I'm an artificial intelligence model, and I don't have a personal history or physical existence, but I can provide information about you if you'd like. I'm a large language model developed by the Meta AI team, and I'm here to assist with a wide range of topics and questions.\n\nAs a conversational AI, I don't have personal experiences, emotions, or physical interactions. I exist solely to provide information and help users like you with their queries. I can draw from my vast knowledge base to provide answers to your questions, but I don't have personal preferences, opinions, or biases.\n\nIf you're interested in learning more about me or our conversation, I can tell you that I'm designed to be helpful, informative, and engaging. I'm constantly learning and improving, and I appreciate the opportunity to interact with users like you.\n\nWhat would you like to talk about, Anusha Khan?"
