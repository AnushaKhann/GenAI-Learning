# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash")

# %%
history = []
while True:
    query = input("User : ")
    
    if query.lower() in ["exit", "quit", "bye"]:
        print("Exiting the chat. Goodbye!")
        break
    
    history.append({"role": "user", "content": query})
    
    res = llm.invoke(history)
    history.append({"role": "ai", "content": res.content})
    
    print("AI", res.content, "\n")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AI [{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': '...'}}]
#
# AI [{'type': 'text', 'text': 'Nice to meet you, Anusha! How can I help you today?', 'extras': {'signature': '...'}}]
#
# AI [{'type': 'text', 'text': 'Your name is Anusha Khan! 😊', 'extras': {'signature': '...'}}]
#
# Exiting the chat. Goodbye!
