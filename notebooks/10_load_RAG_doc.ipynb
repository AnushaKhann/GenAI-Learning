# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Doc Loader - Phase 1

# %%
from langchain_community.document_loaders import TextLoader # PyPDFLoader - for PDF, CSVLoader - for CSV
loader = TextLoader("../data/speech.txt")
texts = loader.load()
texts
# Out:
# [Document(metadata={'source': '../data/speech.txt'}, page_content='“My dear friends, students, and respected farmers,\n\nToday, I want to speak from the heart about three pillars that define the future of our nation:\nour youth, our education system, and our farmers.\n\n🎓 For the Youth\n\nYou are the energy that drives our state forward.\nOur commitment is to give you:\n\t•\tSkill-based education\n\t•\tDigital learning opportunities\n\t•\tBetter employment pathways\n\t•\tSupport for innovation, startups, and entrepreneurship\n\nYour dreams are not just your own—they are the dreams of our entire society.\n\n📚 For Education\n\nEducation must not be just a formality; it must be a force of transformation.\nWe aim to:\n\t•\tUpgrade government schools with smart classrooms\n\t•\tImprove teacher training\n\t•\tExpand scholarships for higher education\n\t•\tPromote technical and vocational courses\n\t•\tEnsure every child gets a fair opportunity to learn and grow\n\nEducation is the foundati
# ...

# %%
oneDoc = texts[0]
print(oneDoc.page_content)
# Out:
# “My dear friends, students, and respected farmers,
#
# Today, I want to speak from the heart about three pillars that define the future of our nation:
# our youth, our education system, and our farmers.
#
# 🎓 For the Youth
#
# You are the energy that drives our state forward.
# Our commitment is to give you:
# 	•	Skill-based education
# 	•	Digital learning opportunities
# 	•	Better employment pathways
# 	•	Support for innovation, startups, and entrepreneurship
#
# Your dreams are not just your own—they are the dreams of our entire society.
#
# 📚 For Education
#
# Education must not be just a formality; it must be a force of transformation.
# We aim to:
# 	•	Upgrade government schools with smart classrooms
# 	•	Improve teacher training
# 	•	Expand scholarships for higher education
# 	•	Promote technical and vocational courses
# 	•	Ensure every child gets a fair opportunity to learn and grow
#
# Education is the foundation on which we will build tomorrow.
#
# 👨‍🌾 For Farmers
#
# ...

# %%
# Web Page Loader
from langchain_community.document_loaders import WebBaseLoader 
loader = WebBaseLoader(web_path="http://geeksforgeeks.org/nlp/what-is-retrieval-augmented-generation-rag/")
docs = loader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
print(docs[0].page_content)
# Out:
# What is Retrieval-Augmented Generation (RAG) - GeeksforGeeksCoursesTutorialsPracticeJobsNLP TutorialLibrariesPhasesText PreprosessingTokenizationLemmatizationWord EmbeddingsProjects IdeasInterview QuestionNLP QuizNLP PipelineDL for NLPShare Your ExperiencesIntroduction to NLPIntroduction to Natural Language Processing (NLP)NLP vs NLU vs NLGApplications of NLPWhy is NLP important?Phases of Natural Language Processing (NLP)The Future of Natural Language Processing: Trends and InnovationsLibraries for NLPNLTK - NLPTokenization Using SpacyPython | Tokenize text using TextBlobIntroduction to Hugging Face TransformersNLP Gensim TutorialNLP Libraries in PythonText Normalization in NLPNormalizing Textual Data with PythonRegex Tutorial - How to write Regular ExpressionsTokenization in NLPLemmatization with NLTKIntroduction to StemmingRemoving stop words with NLTK in PythonPOS(Parts-Of-Speech) Tagging in NLPText Representation and Embedding TechniquesOne-Hot Encoding in NLPBag of words (BoW) m
# ...

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="Retrieval-augmented generation", load_max_docs=2)
docs = loader.load()

# %%
docs[0].page_content
# Out:
# 'Retrieval-augmented generation (RAG) is a technique that enables large language models (LLMs) to retrieve and incorporate new information from external data sources. With RAG, LLMs first refer to a specified set of documents, then respond to user queries. These documents supplement information from the LLM\'s pre-existing training data. This allows LLMs to use domain-specific and/or updated information that is not available in the training data. For example, this enables LLM-based chatbots to access internal company data or generate responses based on authoritative sources. The technique was first proposed in 2020 and has since become a widely adopted approach in modern AI systems.\nRAG improves LLMs by incorporating information retrieval before generating responses. Unlike LLMs that rely on static training data, RAG pulls relevant text from databases, uploaded documents, or web sources. According to Ars Technica, "RAG is a way of improving LLM performance, in essence by blending th
# ...
