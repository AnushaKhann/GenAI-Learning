# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
res = llm.invoke("Hello, I am Anusha Khan. Can you tell me about yourself?")
res.text
# Out:
# 'Hello Anusha! I’m ChatGPT, a conversational AI developed by OpenAI. I’m built on the GPT‑4 architecture and can help you with a wide range of tasks—from answering questions and brainstorming ideas to explaining complex topics and even drafting emails or creative stories. I don’t have personal experiences or feelings, but I’m here to learn from the context you give me and provide useful, accurate, and friendly responses. How can I assist you today?'
